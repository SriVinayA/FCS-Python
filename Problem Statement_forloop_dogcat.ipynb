# %%
for i in range(1,101):
    if i%3==0 and i%5==0:
        print("Dogcat")
    elif i%3==0:
        print("Dog")
    elif i%5==0:
        print("cat")
    else:
        print(i)
# Out:
# 1
# 2
# Dog
# 4
# cat
# Dog
# 7
# 8
# Dog
# cat
# 11
# Dog
# 13
# 14
# Dogcat
# 16
# 17
# Dog
# 19
# cat
# Dog
# 22
# 23
# Dog
# cat
# 26
# Dog
# 28
# 29
# Dogcat
# 31
# 32
# Dog
# 34
# cat
# Dog
# 37
# 38
# Dog
# cat
# 41
# Dog
# 43
# 44
# Dogcat
# 46
# 47
# Dog
# 49
# cat
# Dog
# 52
# 53
# Dog
# cat
# 56
# Dog
# 58
# 59
# Dogcat
# 61
# 62
# Dog
# 64
# cat
# Dog
# 67
# 68
# Dog
# cat
# 71
# Dog
# 73
# 74
# Dogcat
# 76
# 77
# Dog
# 79
# cat
# Dog
# 82
# 83
# Dog
# cat
# 86
# Dog
# 88
# 89
# Dogcat
# 91
# 92
# Dog
# 94
# cat
# Dog
# 97
# 98
# Dog
# cat
